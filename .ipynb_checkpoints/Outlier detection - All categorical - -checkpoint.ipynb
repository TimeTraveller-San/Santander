# %% [markdown]
# # Improts

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import StratifiedKFold, train_test_split
import scikitplot as skplt
from sklearn.metrics import roc_auc_score
import lightgbm as lgb
import pickle
import gc

# %%
def augment_probs(mydf):
    info = {}
    for var in mydf.columns:
        if var in ['ID_code', 'target']:
            continue
        IQR = mydf[var].quantile([0.75]).values - mydf[var].quantile([0.25]).values 
        n = mydf.shape[0] 
        bin_size = 2.5 * IQR / (n ** (1/3)) 
        bin_number = int((mydf[var].max() - mydf[var].min())/bin_size)
        key = var
        mydf[key] = pd.cut(mydf[var], bins = bin_number, labels = range(bin_number)).astype('float')
        info[var] = {
            'bin' : bin_number,
        }
    return mydf, info

def test_augment_probs(mydf, info):
    for var in mydf.columns:
        if var in ['ID_code', 'target']:
            continue
        bin_number = info[var]['bin']
        key = var
        mydf[key] = pd.cut(mydf[var], bins = bin_number, labels = range(bin_number)).astype('float')
    return mydf

# %%
train_df = pd.read_csv('data/train.csv')
test_df = pd.read_csv('data/test.csv')

# %%
train_df, info = augment_probs(train_df)

# %%
test_df = test_augment_probs(test_df, info)

# %%
X_train = train_df.drop(['ID_code', 'target'], axis=1)
y_train = train_df.target
Xtr, Xval, ytr, yval  = train_test_split(X_train, y_train, test_size = 0.05)

# %%
def save_model(models, filename):
    with open(filename, 'wb') as handle:
        pickle.dump(models, handle)
        
def augment(x,y,t=2):
    xs,xn = [],[]
    for i in range(t):
        mask = y>0
        x1 = x[mask].copy()
        ids = np.arange(x1.shape[0])
        for c in range(x1.shape[1]):
            np.random.shuffle(ids)
            x1[:,c] = x1[ids][:,c]
        xs.append(x1)

    for i in range(t//2):
        mask = y==0
        x1 = x[mask].copy()
        ids = np.arange(x1.shape[0])
        for c in range(x1.shape[1]):
            np.random.shuffle(ids)
            x1[:,c] = x1[ids][:,c]
        xn.append(x1)
    xs = np.vstack(xs)
    xn = np.vstack(xn)
    ys = np.ones(xs.shape[0])
    yn = np.zeros(xn.shape[0])
    x = np.vstack([x,xs,xn])
    y = np.concatenate([y,ys,yn])
    return x,y

def lgb_trainer(X, y, params, n_folds):
    skf = StratifiedKFold(n_splits=n_folds)
    models = []
    for train_idx, test_idx in skf.split(X.values, y.values):
            gc.collect()
            X_train, y_train = X.iloc[train_idx], y.iloc[train_idx]
            X_tr, y_tr = augment(X_train.values, y_train.values)
            X_tr = pd.DataFrame(X_tr)
            trn_data = lgb.Dataset(X_tr, label=y_tr)
            test_data = lgb.Dataset(X.values[test_idx], label=y.values[test_idx])
            model_lgb     = lgb.train(param, trn_data, 1000000, valid_sets = [trn_data, test_data], verbose_eval=5000, early_stopping_rounds = 4000)
            models.append(model_lgb)
            auc = roc_auc_score(y.values[test_idx], model_lgb.predict(X.values[test_idx]))
    return models

def lgb_trainer_no_aug(X, y, params, n_folds):
    skf = StratifiedKFold(n_splits=n_folds)
    models = []
    for train_idx, test_idx in skf.split(X.values, y.values):
            gc.collect()
            X_train, y_train = X.iloc[train_idx], y.iloc[train_idx]
            X_tr, y_tr = X_train.values, y_train.values
            X_tr = pd.DataFrame(X_tr)
            trn_data = lgb.Dataset(X_tr, label=y_tr)
            test_data = lgb.Dataset(X.values[test_idx], label=y.values[test_idx])
            model_lgb     = lgb.train(param, trn_data, 1000000, valid_sets = [trn_data, test_data], verbose_eval=5000, early_stopping_rounds = 4000)
            models.append(model_lgb)
            auc = roc_auc_score(y.values[test_idx], model_lgb.predict(X.values[test_idx]))
    return models

def test(X, y, models):
    preds = pd.DataFrame({})
    for i, model in enumerate(models):
        preds[str(i)] = model.predict(X)
        print(f"Fold: {i} \t Score: {roc_auc_score(y, preds[str(i)].values)}")
    averaged_preds = preds.mean(axis=1)
    print(f"Score: {roc_auc_score(y, averaged_preds)}")
    return averaged_preds, preds

# %%
param = {
    'bagging_freq': 5,
    'bagging_fraction': 0.335,
    'boost_from_average':'false',
    'boost': 'gbdt',
    'feature_fraction': 0.041,
    'learning_rate': 0.0083,
    'max_depth': -1,
    'metric':'auc',
    'min_data_in_leaf': 80,
    'min_sum_hessian_in_leaf': 10.0,
    'num_leaves': 13,
    'num_threads': 8,
    'tree_learner': 'serial',
    'objective': 'binary', 
    'verbosity': -1,
}

# %%
first_models_v = lgb_trainer(Xtr, ytr, param, n_folds = 10)
# Out:
# Training until validation scores don't improve for 4000 rounds.
# [5000]	training's auc: 0.91183	valid_1's auc: 0.897869
# [10000]	training's auc: 0.921669	valid_1's auc: 0.901173
# [15000]	training's auc: 0.928897	valid_1's auc: 0.901358
# Early stopping, best iteration is:
# [14144]	training's auc: 0.927725	valid_1's auc: 0.901507
# Training until validation scores don't improve for 4000 rounds.
# [5000]	training's auc: 0
# Training until validation scores don't improve for 4000 rounds.
# [5000]	training's auc: 0.924753	valid_1's auc: 0.89933
# [10000]	training's auc: 0.939801	valid_1's auc: 0.900482
# Early stopping, best iteration is:
# [8728]	training's auc: 0.936317	valid_1's auc: 0.900598
# Training until validation scores don't improve for 4000 rounds.
# [5000]	training's auc: 0.924224	valid_1's auc: 0.902152
# [10000]	training's auc: 0.939549	valid_1's auc: 0.903424
# Early stopping, best iteration is:
# [8757]	training's auc: 0.936108	valid_1's auc: 0.903643
# Training until validation scores don't improve for 4000 rounds.
# [5000]	training's auc: 0.925398	valid_1's auc: 0.889232
# [10000]	training's auc: 0.940458	valid_1's auc: 0.891354
# Early stopping, best iteration is:
# [10844]	training's auc: 0.942661	valid_1's auc: 0.891619
# Training until validation scores don't improve for 4000 rounds.
# [5000]	training's auc: 0.924414	valid_1's auc: 0.902548
# [10000]	training's auc: 0.939582	valid_1's auc: 0.904079
# [15000]	training's auc: 0.951849	valid_1's auc: 0.903976
# Early stopping, best iteration is:
# [11928]	training's auc: 0.94457	valid_1's auc: 0.904143
# Training until validation scores don't improve for 4000 rounds.
# [5000]	training's auc: 0.924547	valid_1's auc: 0.900518
# [10000]	training's auc: 0.939715	valid_1's auc: 0.902589
# [15000]	training's auc: 0.951977	valid_1's auc: 0.902426
# Early stopping, best iteration is:
# [12696]	training's auc: 0.946564	valid_1's auc: 0.902746
# Training until validation scores don't improve for 4000 rounds.
# [5000]	training's auc: 0.924905	valid_1's auc: 0.89795
# [10000]	training's auc: 0.940104	valid_1's auc: 0.899382
# Early stopping, best iteration is:
# [8174]	training's auc: 0.935046	valid_1's auc: 0.899507

# %%
q, w = test(Xval, yval, first_models_v)
# Out:
# Fold: 0 	 Score: 0.8971929743353916
# Fold: 1 	 Score: 0.897355430502694
# Fold: 2 	 Score: 0.8982592816083184
# Fold: 3 	 Score: 0.8972756000116726
# Fold: 4 	 Score: 0.8971582022307591
# Fold: 5 	 Score: 0.8977126551789025
# Fold: 6 	 Score: 0.8964722637679925
# Fold: 7 	 Score: 0.8974089862522726
# Fold: 8 	 Score: 0.8970376738423544
# Fold: 9 	 Score: 0.8966294649870062
# Score: 0.8980648485216433

# %%
q, w = test(Xval, yval, first_models_no_aug)
# Out:
# Fold: 0 	 Score: 0.8951358297915539
# Fold: 1 	 Score: 0.8957528948895181
# Fold: 2 	 Score: 0.895917475397618
# Fold: 3 	 Score: 0.8952897885956664
# Fold: 4 	 Score: 0.8952024670081488
# Fold: 5 	 Score: 0.8962828620147851
# Fold: 6 	 Score: 0.8967149976559576
# Fold: 7 	 Score: 0.8962599414956546
# Fold: 8 	 Score: 0.8965677472964688
# Fold: 9 	 Score: 0.8953598918419836
# Score: 0.8966730698770599

# %%
Xval.shape
# Out:
# (10000, 202)

# %%
q.isna().any()
# Out:
# False

# %%
q.shape
# Out:
# (10000,)

# %%
Xval['preds'] = q.values
Xval['target'] = yval
# Out:
# /home/timetraveller/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /home/timetraveller/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
Xval[Xval.target == 1][Xval.preds < 0.5]
# Out:
# /home/timetraveller/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#         var_0  var_1  var_2  var_3  var_4  var_5  var_6  var_7  var_8  var_9
# 74867    ...       37.0     84.0     54.0     48.0     68.0     47.0     35.0
# 153969   ...       50.0     93.0     61.0     67.0     77.0     61.0     34.0
#
#         var_199     preds  target
# 51384      50.0  0.475909       1
# 137302     51.0  0.093787       1
# 173590     69.0  0.120679       1
# 194932     43.0  0.114067       1
# 4516       39.0  0.077888       1
# 199578     51.0  0.075114       1
# 99587      52.0  0.191603       1
# 91339      63.0  0.488347       1
# 110009     42.0  0.116631       1
# 124994     56.0  0.278273       1
# 123812     68.0  0.244973       1
# 117120     66.0  0.045628       1
# 164141     30.0  0.188781       1
# 72756      51.0  0.102235       1
# 151815     73.0  0.419451       1
# 51079      26.0  0.370238       1
# 62317      74.0  0.383368       1
# 160665     60.0  0.120900       1
# 126525     66.0  0.115841       1
# 115909     61.0  0.475200       1
# 19214      35.0  0.377887       1
# 30185      53.0  0.238191       1
# 144297     41.0  0.054640       1
# 192533     68.0  0.393902       1
# 52325      21.0  0.292348       1
# 172828     40.0  0.120091       1
# 43138      57.0  0.454442       1
# 8312       45.0  0.346412       1
# 178110     56.0  0.372942       1
# 138924     58.0  0.376466       1
# ...         ...       ...     ...
# 132431     10.0  0.264036       1
# 133730     63.0  0.138801       1
# 96877      20.0  0.187700       1
# 37019      48.0  0.403629       1
# 25188      25.0  0.210210       1
# 177936     75.0  0.084649       1
# 74148      50.0  0.116373       1
# 64355      62.0  0.139625       1
# 61838      65.0  0.199990       1
# 111905     45.0  0.482581       1
# 186654     80.0  0.284914       1
# 78560      53.0  0.319120       1
# 69650      73.0  0.185045       1
# 77880      58.0  0.127475       1
# 2111       62.0  0.431678       1
# 37571      38.0  0.022146       1
# 151649     53.0  0.022113       1
# 17962      45.0  0.477422       1
# 49011      38.0  0.052975       1
# 189746     50.0  0.463955       1
# 140889     67.0  0.205210       1
# 126577     53.0  0.224259       1
# 64446      57.0  0.333305       1
# 36979      47.0  0.051125       1
# 18444      80.0  0.198501       1
# 137629     56.0  0.124857       1
# 136880     49.0  0.419074       1
# 177106     46.0  0.037664       1
# 74867      74.0  0.473896       1
# 153969     53.0  0.345381       1
#
# [665 rows x 202 columns]

# %%
Xval[Xval.target == 0][Xval.preds > 0.5]
# Out:
# /home/timetraveller/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#         var_0  var_1  var_2  var_3  var_4  var_5  var_6  var_7  var_8  var_9  \
# 93500    58.0   61.0   53.0   47.0   31.0   87.0   35.0   55.0   66.0   38.0
# 134249   79.0   75.0   38.0   61.0   76.0   45.0   87.0   36.0   18.0   62.0
# 118547   72.0   61.0   48.0   61.0   71.0   55.0   52.0   59.0   49.0   26.0
# 84797    47.0   73.0   53.0   76.0   56.0   84.0   77.0   44.0   38.0   49.0
# 136967   57.0   46.0   79.0   75.0   55.0   52.0   53.0   58.0   34.0   27.0
# 64371    61.0   56.0   87.0   67.0   37.0   55.0   72.0   59.0   39.0    8.0
# 168063   48.0   23.0   45.0   74.0   61.0   52.0   68.0   24.0   53.0   18.0
# 37854    73.0   65.0   48.0   66.0   54.0   53.0   59.0   61.0   67.0   31.0
# 173255   37.0   48.0   38.0   57.0   50.0   35.0   41.0   28.0   39.0   47.0
# 53934    70.0   21.0   48.0   61.0   69.0   34.0   64.0   24.0   39.0   37.0
# 76362      54.0  0.522280       0
# 41944      64.0  0.571683       0
# 92693      45.0  0.674976       0
# 96409      58.0  0.740943       0
# 67131      61.0  0.535917       0
# 18448      48.0  0.614019       0
# 69633      52.0  0.601591       0
# 110537     45.0  0.541410       0
# 87463      41.0  0.690270       0
# 19674      62.0  0.623086       0
# 39729      46.0  0.523092       0
# 66515      22.0  0.522792       0
# 62438      64.0  0.921196       0
# 156342     54.0  0.622728       0
# 100450     50.0  0.640056       0
# 36100      63.0  0.649635       0
# ...         ...       ...     ...
# 157893     61.0  0.525129       0
# 126753     75.0  0.811528       0
# 38385      64.0  0.504039       0
# 37479      58.0  0.807535       0
# 58236      67.0  0.561835       0
# 188003     28.0  0.853358       0
# 125618     62.0  0.545703       0
# 187488     63.0  0.544266       0
# 110834     23.0  0.536242       0
# 96613      59.0  0.696760       0
# 185776     73.0  0.548880       0
# 55672      66.0  0.562120       0
# 195296     75.0  0.545048       0
# 197168     42.0  0.531365       0
# 121006     43.0  0.655700       0
# 132659     35.0  0.546941       0
# 151701     61.0  0.642826       0
# 20341      79.0  0.854457       0
# 14719      60.0  0.832479       0
# 116329     59.0  0.567995       0
# 152244     51.0  0.733948       0
# 166283     52.0  0.516923       0
# 146938     46.0  0.716617       0
# 114045     31.0  0.768220       0
# 116550     34.0  0.803302       0
# 116378     45.0  0.555527       0
# 189432     61.0  0.800441       0
# 14744      59.0  0.625926       0
# 159800     60.0  0.804783       0
# 196911     47.0  0.668808       0
#
# [94 rows x 202 columns]

# %% [markdown]
# # Test

# %%
from scipy.special import erfc
import scipy
plt.style.use('seaborn')

# %%
def chauvenet(array):
    mean = array.mean()           # Mean of incoming array
    stdv = array.std()            # Standard deviation
    N = len(array)                # Lenght of incoming array
    criterion = 1.0/(2*N)         # Chauvenet's criterion
    d = abs(array-mean)/stdv      # Distance of a value to mean in stdv's
    prob = erfc(d)                # Area normal dist.    
    return prob < criterion       # Use boolean array outside this function

# %%
train_df.head()
# Out:
#    ID_code  target    var_0   var_1    var_2   var_3    var_4   var_5   var_6  \
# 0  train_0       0   8.9255 -6.7863  11.9081  5.0930  11.4607 -9.2834  5.1187
# 1  train_1       0  11.5006 -4.1473  13.8588  5.3890  12.3622  7.0433  5.6208
# 2  train_2       0   8.6093 -2.7457  12.0805  7.8928  10.5825 -9.0837  6.9427
# 3  train_3       0  11.0604 -2.1518   8.9522  7.1957  12.5846 -1.8361  5.8428
# 4  train_4       0   9.8369 -1.4834  12.8746  6.6375  12.2772  2.4486  5.9405
#
#      var_7   ...     var_190  var_191  var_192  var_193  var_194  var_195  \
# 0  18.6266   ...      4.4354   3.9642   3.1364   1.6910  18.5227  -2.3978
# 1  16.5338   ...      7.6421   7.7214   2.5837  10.9516  15.4305   2.0339
# 2  14.6155   ...      2.9057   9.7905   1.6704   1.6858  21.6042   3.1417
# 3  14.9250   ...      4.4666   4.7433   0.7178   1.4214  23.0347  -1.2706
# 4  19.2514   ...     -1.4905   9.5214  -0.1508   9.1942  13.2876  -1.5121
#
#    var_196  var_197  var_198  var_199
# 0   7.8784   8.5635  12.7803  -1.0914
# 1   8.1267   8.7889  18.3560   1.9518
# 2  -6.5213   8.2675  14.7222   0.3965
# 3  -2.9275  10.2922  17.9697  -8.9996
# 4   3.9267   9.5031  17.9974  -8.8104
#
# [5 rows x 202 columns]

# %%
outliers = dict()
for col in [col for col in train_df.columns if col not in ['ID_code', 'target']]:
    outliers[col] = train_df[chauvenet(train_df[col].values)].shape[0]
outliers = pd.Series(outliers)
outliers.sort_values().plot(figsize=(14, 40), kind='barh').set_xlabel('Number of outliers');

# %%
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-11-c4ec70a6e8fa> in <module>
#       1 outliers = dict()
#       2 for col in [col for col in train_df.columns if col not in ['ID_code', 'target']]:
# ----> 3     outliers[col] = train_df[chauvenet(train_df[col].values)][col]
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2680         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2681             # either boolean or fancy integer index
# -> 2682             return self._getitem_array(key)
#    2683         elif isinstance(key, DataFrame):
#    2684             return self._getitem_frame(key)
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2722             key = check_bool_indexer(self.index, key)
#    2723             indexer = key.nonzero()[0]
# -> 2724             return self._take(indexer, axis=0)
#    2725         else:
#    2726             indexer = self.loc._convert_to_indexer(key, axis=1)
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/generic.py in _take(self, indices, axis, is_copy)
#    2787         new_data = self._data.take(indices,
#    2788                                    axis=self._get_block_manager_axis(axis),
# -> 2789                                    verify=True)
#    2790         result = self._constructor(new_data).__finalize__(self)
#    2791
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/internals.py in take(self, indexer, axis, verify, convert)
#    4537         new_labels = self.axes[axis].take(indexer)
#    4538         return self.reindex_indexer(new_axis=new_labels, indexer=indexer,
# -> 4539                                     axis=axis, allow_dups=True)
#    4540
#    4541     def merge(self, other, lsuffix='', rsuffix=''):
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/internals.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy)
#    4423             new_blocks = [blk.take_nd(indexer, axis=axis, fill_tuple=(
#    4424                 fill_value if fill_value is not None else blk.fill_value,))
# -> 4425                 for blk in self.blocks]
#    4426
#    4427         new_axes = list(self.axes)
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/internals.py in <listcomp>(.0)
#    4423             new_blocks = [blk.take_nd(indexer, axis=axis, fill_tuple=(
#    4424                 fill_value if fill_value is not None else blk.fill_value,))
# -> 4425                 for blk in self.blocks]
#    4426
#    4427         new_axes = list(self.axes)
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/internals.py in take_nd(self, indexer, axis, new_mgr_locs, fill_tuple)
#    1256             fill_value = fill_tuple[0]
#    1257             new_values = algos.take_nd(values, indexer, axis=axis,
# -> 1258                                        allow_fill=True, fill_value=fill_value)
#    1259
#    1260         if new_mgr_locs is None:
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/algorithms.py in take_nd(arr, indexer, axis, out, fill_value, mask_info, allow_fill)
#    1653             out = np.empty(out_shape, dtype=dtype, order='F')
#    1654         else:
# -> 1655             out = np.empty(out_shape, dtype=dtype)
#    1656
#    1657     func = _get_take_nd_function(arr.ndim, arr.dtype, out.dtype, axis=axis,
#
# MemoryError:
