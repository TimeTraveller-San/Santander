# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, ParameterGrid
import pickle
from sklearn.metrics import roc_auc_score
import seaborn as sns
import lightgbm as lgb
from sklearn.metrics import roc_auc_score
TRAIN = 'data/train.csv'
TEST = 'data/test.csv'
WHOLE = 'whole.csv'
SAMPLE = 'data/sample_submission.csv'
# train = pd.read_csv(TRAIN)
# test = pd.read_csv(TEST)
whole = pd.read_csv(WHOLE)

# %%
from tqdm import tqdm

# %%
traindf, testdf = whole[:200000], whole[200000:]

# %%
traindf.head()
# Out:
#    ID_code  target    var_0   var_1  var_10  var_100  var_101  var_102  \
# 0  train_0     0.0   8.9255 -6.7863  2.9252   9.4763  13.3102  26.5376
# 1  train_1     0.0  11.5006 -4.1473 -0.4032 -13.6950   8.4068  35.4734
# 2  train_2     0.0   8.6093 -2.7457 -0.3249  -0.3939  12.6317  14.8863
# 3  train_3     0.0  11.0604 -2.1518  2.3061 -19.8592  22.5316  18.6129
# 4  train_4     0.0   9.8369 -1.4834 -9.4458 -22.9264  12.3562  17.3410
#
#    var_103  var_104      ...       count_var_90  count_var_91  count_var_92  \
# 0   1.4403  14.7100      ...                  1            51             3
# 1   1.7093  15.1866      ...                  1            77             3
# 2   1.3854  15.0284      ...                  1            72             6
# 3   1.3512   9.3291      ...                  1            62             2
# 4   1.6940   7.1179      ...                  1            65             3
#
#    count_var_93  count_var_94  count_var_95  count_var_96  count_var_97  \
# 0            18             3            20             2             1
# 1            24             4             3             1             2
# 2            26             6            17             2             1
# 3            24             1             4             3             1
# 4            16             2            18             1             1
#
#    count_var_98  count_var_99
# 0            14             4
# 1            15             5
# 2            22             8
# 3             9             3
# 4            15             3
#
# [5 rows x 402 columns]

# %%
import seaborn as sns
for i, col in enumerate(traindf.columns):
    if col[0] != 'c':
        continue
    sns.kdeplot(traindf[col])
    sns.kdeplot(testdf[col])
    plt.legend(['Train', 'Test'])
    plt.title(f"Column: {col}")
    plt.show()
    if i % 2 == 0:
        break
